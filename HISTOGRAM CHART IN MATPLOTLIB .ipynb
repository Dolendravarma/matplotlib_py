# %% [markdown]
# #HISTOGRAM CHART IN MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [48 12 53 14 30 59 32 32 54 20 54 12 55 48 42 22 57 41 10 31 45 34 33 48
#  37 30 55 50 58 18 53 29 56 48 33 47 50 23 33 51 14 27 16 18 43 20 17 53
#  33 26]

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='red',bins=7,edgecolor='blue')
# The bins parameter in plt.hist() is used to define the number of intervals (bins) or the specific edges of those intervals into which your data points are grouped when creating a histogram.

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,'auto',(0,100),edgecolor='blue')
#'auto' specifies the method used to automatically determine the number of bins. 


plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',cumulative=-1)
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left')
# The histtype parameter accepts several values, with step being one of them.

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',histtype='step')
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.
# bottom parameter is used to specify the location of the bottom edge of the bars in the histogram. 

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',histtype='stepfilled')
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.
# bottom parameter is used to specify the location of the bottom edge of the bars in the histogram. 
# histtype='stepfilled': This creates a histogram where the bars are drawn as steps (like in histtype='step'), but the area beneath these steps is filled with color

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',histtype='barstacked')
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.
# bottom parameter is used to specify the location of the bottom edge of the bars in the histogram. 
# histtype='barstacked': This creates a histogram where the bars are drawn as steps (like in histtype='step'), but the area beneath these steps is filled with color

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',histtype='bar')
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.
# bottom parameter is used to specify the location of the bottom edge of the bars in the histogram. 
# histtype='bar': This creates a histogram where the bars are drawn as steps (like in histtype='step'), but the area beneath these steps is filled with color

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',histtype='step')
#'auto' specifies the method used to automatically determine the number of bins. 
# When you set cumulative=-1, it creates a reverse cumulative histogram.
# bottom parameter is used to specify the location of the bottom edge of the bars in the histogram. 
# histtype='step': This creates a histogram where the bars are drawn as steps (like in histtype='step'), but the area beneath these steps is filled with color

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',bottom=20,align='left',orientation='horizontal')
#  By default, the histogram bars are vertical, but you can change this to horizontal by setting orientation='horizontal'.

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',align='left',rwidth=0.3)
#  By default, the histogram bars are vertical, but you can change this to horizontal by setting orientation='horizontal'.
# The rwidth parameter in the plt.hist() function controls the relative width of the bars in the histogram. It is a fraction of the bin width, and it helps in adjusting the spacing between bars.

plt.title('Histogram')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',log=True,bins=9,label='Python')
#  By default, the histogram bars are vertical, but you can change this to horizontal by setting orientation='horizontal'.
# The rwidth parameter in the plt.hist() function controls the relative width of the bars in the histogram. It is a fraction of the bin width, and it helps in adjusting the spacing between bars.

plt.title('Histogram')
plt.legend()
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
np=[48,12 ,53 ,14 ,30 ,59 ,32 ,32 ,54 ,20, 54, 12 ,55 ,48, 42, 22 ,57, 41, 10 ,31 ,45 ,34 ,33 ,48,
 37 ,30 ,55 ,50, 58 ,18, 53, 29, 56, 48 ,33 ,47 ,50 ,23, 33, 51, 14 ,27, 16, 18 ,43, 20, 17, 53,
 33, 26]

l=[10,20,30,40,50,60]
plt.hist(np,color='green',edgecolor='blue',log=True,bins=9,label='Python')
#  By default, the histogram bars are vertical, but you can change this to horizontal by setting orientation='horizontal'.
# The rwidth parameter in the plt.hist() function controls the relative width of the bars in the histogram. It is a fraction of the bin width, and it helps in adjusting the spacing between bars.

plt.title('Histogram')

plt.axvline(30,color='r',label='line')

plt.xlabel('python')
plt.ylabel('No')
plt.legend()
plt.grid()
plt.show()
